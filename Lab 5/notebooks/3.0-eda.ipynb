# %% [markdown]
# <div style="text-align: center; background-color: #559cff; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 20px; font-size: 40px; font-weight: bold; border-radius: 0 0 0 0; box-shadow: 0px 6px 8px rgba(0, 0, 0, 0.2);">
#   Lab 02 - Introduction To Data Science @ FIT-HCMUS, VNU-HCM 📌
# </div>

# %% [markdown]
# <div style="text-align: center; background-color: #b1d1ff; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 20px; font-size: 40px; font-weight: bold; border-radius: 0 0 0 0; box-shadow: 0px 6px 8px rgba(0, 0, 0, 0.2);">
#   Stage 3.0 - Exploratory data analysis
# </div>

# %% [markdown]
# ## Import

# %%
import os
import sys

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# YOUR CODE HERE (OPTION) 
# If you need other libraries, you can import them here
import seaborn as sns

# %% [markdown]
# ## Exploring your data

# %% [markdown]
# ### Read cleaned data from file (0.25 points)

# %% [markdown]
# We can now use the cleaned dataset for analysis. Thus, we first read the CSV files we created in the previous pre-processing task.

# %%
# YOUR CODE HERE
cleaned_df = pd.read_csv("../data/processed/21127528_asia_processed.csv")

# %%
# TEST
cleaned_df.head()
# Out:
#    Total Population  Female Population  Male Population  Birth Rate  \
# 0        41128771.0         20362329.0       20766442.0   20.700378
# 1        40099462.0         19844584.0       20254878.0   35.842000
# 2        38972230.0         19279929.0       19692301.0   36.051000
# 3        37769499.0         18679090.0       19090409.0   36.466000
# 4        36686784.0         18136922.0       18549862.0   36.927000
#
#    Death Rate  Compulsory Education Dur.  Employment in Industry(%)  \
# 0    6.343087                        9.0                   21.36864
# 1    7.344000                        9.0                   21.36864
# 2    7.113000                        9.0                   18.48131
# 3    6.791000                        9.0                   18.33941
# 4    6.981000                        9.0                   18.12015
#
#    Employment in Agriculture(%)  Female Employment in Agriculture(%)  \
# 0                     28.950359                            31.756573
# ...

# %%
# TEST
cleaned_df.shape
# Out:
# (1316, 25)

# %% [markdown]
# ### Numerical analysis using descriptive statistics (0.25 points)

# %% [markdown]
# Descriptive statistics show the characteristics of numerical features. It shows us the information such as:
# - The mean (and you can go further with advanced techiques as Arithmetic mean, Geometric mean, Harmonic mean)
# - The median
# - The mode
# - Quantiles (Quartiles, Percentiles, Deciles, Crocodiles?)
# - Range and IQR (Interquartile Range) (you might find that its relation to box plots)
# - Variance and Standard deviation (std dev)
# - Coefficient of Variation
# - Skewness
# - Kurtosis
# - Standard Error (of the sample mean)
# - Moments
# - Covariance and Correlation
#
# Due the scope of this lab, you just need to use basic function of Pandas to calculate basic descriptive statistics information and give insights from it.

# %%
df_copy = cleaned_df.drop(['Year', 'Country'], axis='columns')

# YOUR CODE HERE
df_copy.describe()
# Out:
#        Total Population  Female Population  Male Population   Birth Rate  \
# count      1.316000e+03       1.316000e+03     1.316000e+03  1316.000000
# mean       9.020217e+07       4.433594e+07     4.586623e+07    20.700378
# std        2.549317e+08       1.240024e+08     1.309465e+08     7.692176
# min        2.582080e+05       1.249510e+05     1.332570e+05     5.100000
# 25%        4.382818e+06       2.121473e+06     2.311564e+06    15.272250
# 50%        1.822701e+07       9.013542e+06     9.061772e+06    20.216500
# 75%        6.135766e+07       3.051728e+07     3.080141e+07    24.321000
# max        1.417173e+09       6.915285e+08     7.311805e+08    52.073000
#
#         Death Rate  Compulsory Education Dur.  Employment in Industry(%)  \
# count  1316.000000                1316.000000                1316.000000
# mean      6.343087                   8.913545                  21.368640
# std       2.669834                   1.797383                   7.752528
# ...

# %% [markdown]
# **TODO**: Give your obervation here
#
# * From the given dataframe, at the **count** row, it is observed that there is only 3 columns tagged *Total Population*, *Female Population* and *Male Population* having enough data on total 1316 lines. Most of features don't fill up all 1316 rows, in terms of **literacy rate**, the data only lie in 267/1316 rows.
# * At the **mean** row, it's clearly that birth rate is quite low in Asia with just 20.7. It's also shown that the average portion employment of women in agriculture is relative high comparing with industrial field.
# * I will have some comment on the economical development of Asia based on **mean** and **std (standard deviation)** index and the two features taken into consideration are **GDP in USD** and **Net income from Abroad**. The table statistictis show us:
#     * On average, the GDP is around 445.78 billion USD - central value of data. In addition, the standard deviation is quite high, about nearly 1.48 trillion USD; this number tells us a wide disperation of data. From both of the feature number, it is concluded that from the data point of mean value, the GPD in USD data across Asia vary in a large range that up to trillions of USD.
#     * In term of **Net income from Abroad**, we can observe that there exists negative values in **Mean**. This index indicate that on average, countries in Asia experience net loss; it's synonymous with the fact that expenses spent on operation, factory or investment outweight the profit produced in the net income abroad. **Std** of approximately 25.35 billion indicates a high variability in the net from abroad. In columns **Min** and **Max** with -192.8 billion and 242.99 billion respectively, such a high variability might provide a potential prediction for significant outliers in the data, which present heavy impact on the overall performance for the economical operation in Asia.
# * The appearance of number 0 in the statistic table all lies in the issue of energy consumption including **Renewable Energy Consumption** and **Fossil Fuel Comsumption**. This indicates that there exists third-world country have no renewable energy consumption in a particular year, while existing developed country in Asia that consume 0% fossil fuel for energy in a year but using renewable ones or maybe nuclear power instead.
#
#
#
#
# ...

# %% [markdown]
# ### Describe the correlation between features in the dataset (0.75 points)

# %% [markdown]
# Considering the available features within the training dataset, we want to identify and analyse the relationships between them, and then determine which features within the dataset significantly contribute to our solution goal. By using calculation and visualisation, Python allows us to create a correlation matrix, which is a table that represents the correlation coefficients between different variables.

# %% [markdown]
# Now let's make a correlation matrix, then visualize it, and describe what insights you observed?

# %%
# PRE-PROCESSING IF NEEDED
# YOUR CODE HERE (OPTION)

# %%
# YOUR CODE HERE
# create a copy
df_copy = cleaned_df.copy()

# Exclude the categorical features from the matrix
df_copy.drop(['Year', 'Country'], inplace=True, axis='columns')

# plot a correlation matrix
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(df_copy.corr(), cmap='RdBu', center=0,ax=ax)
plt.show()

# %% [markdown]
# * From the correlation map, **National income per Capita**, **Net income from Abroad** and **Compulsory Education Dur.** seem to have no strong relation with other features.
# * Concern relation in employment, there is a tight relationship between two sectors: agriculture and industry. It can be seen that employments in agriculture (including female employment) and industry are in inverse relation.This implies that an increase in the proportion of employment in industry will lead to a decrease in the agricultural workforce.
# * Besides that, in the group concluding **Electric Power Consumption**, **Renewable Energy Consumption**, **Fossil Fuel Consumption**, **Male life expectancy** and **Female life expectancy**, this area is highlighted with dark blue except for **Renewable Energy Consumption**. Dark blue show that correlation coefficient is near with value 1 so that these features have positive influence on each other. **Renewable Energy Consumption**, on the other hand, is colored in red showing inverse relation with other features in the mentioned group. It is reasonably understood that the more we use renewable energy, the good effect on different fields is also clearly described, - fossil fuel and electric power comsumed drop. However, its relationship with life expectancy is quite weak.
# * A remarkable connection is witnessed among the **(Female) Employment in Agriculture** with the group concluding **Electric Power Consumption**, **Renewable Energy Consumption**, **Fossil Fuel Consumption**, **Male life expectancy** and **Female life expectancy**. The development of Agriculture company with the growth of renewable energy consumption; but somehow make a contribution to the decrease in portion of fossil fuel, deployed electric power, espcially male/ female life expectancy. I suppose that due to the poisonous working environment with pesticide, fertilize or heavy sun ray, human life expectancy is shortened greatly.

# %% [markdown]
# **Question 01**: How does the correlation between features change in the top 10 countries with the LARGEST population?
#
# When we have an answer for this question, we might see how features interaction with each other when the conutry population is large.

# %%
# PRE-PROCESSING IF NEEDED
# YOUR CODE HERE (OPTION)
df_copy = cleaned_df.copy()
des_df = df_copy.sort_values(by='Total Population', ascending = False).reset_index(drop=True).loc[0:9]
des_df
# Out:
#    Total Population  Female Population  Male Population  Birth Rate  \
# 0      1.417173e+09        685992675.0      731180498.0   20.700378
# 1      1.412360e+09        691219627.0      721140373.0    7.520000
# 2      1.412175e+09        691528501.0      720646499.0   20.700378
# 3      1.411100e+09        690171847.0      720928153.0    8.520000
# 4      1.407745e+09        688179990.0      719565010.0   10.410000
# 5      1.407564e+09        681060413.0      726503429.0   16.419000
# 6      1.402760e+09        685468977.0      717291023.0   10.860000
# 7      1.396387e+09        675389679.0      720997448.0   16.572000
# 8      1.396215e+09        682006802.0      714208198.0   12.640000
# 9      1.387790e+09        677689913.0      710100087.0   13.570000
#
#    Death Rate  Compulsory Education Dur.  Employment in Industry(%)  \
# 0    6.343087                        8.0                   21.36864
# 1    7.180000                        9.0                   28.24155
# ...

# %%
# YOUR CODE HERE

df_copy = cleaned_df.copy()
des_df = df_copy.sort_values(by='Total Population', ascending = False).reset_index(drop=True).loc[0:9]
des_df.drop(['Year', 'Country','Electric Power Consumption(kWH per capita)','Fossil Fuel Consumption (%)','Primary completion rate'], inplace=True, axis='columns')

fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(des_df.corr(), cmap='RdBu',center=0,ax=ax)
plt.show()

# %% [markdown]
# * After printing out the dataframe, I observe that there exists 3 columns that are filled with quite similar data : **Electric Power Consumption(kWH per capita)**, **Fossil Fuel Consumption (%)**, **Primary completion rate**. Therefore, there is no point in keeping 3 columns as they cant help us to bring out any useful analysis on the correlation.

# %% [markdown]
# **YOUR ANSWER**

# %% [markdown]
# * After plotting data with heat map, I found out that in top 10 countries with largest population, almost any fields have strong connection with each others, both positively and negatively.
# * To talk about the least influence, it lies in 2 features **Net Income from Abroad**, **School enronment, Primary**.
# * With inverse correlation, **Female/Employment in Agriculture** possess the most impact. Increasing work force in agriculture leads to the intensive drop in the portion of other majors like industry; especially in **GDP in USD**, educational issues: **Compulsory Education Dur.**, **School enrollment, tertiary** and **Literacy rate** and human life expectancy.

# %% [markdown]
# **Question 02**: How does the correlation between features change in the top 10 countries with the SMALLEST population?
#
# When we have an answer for this question, we might see how features interaction with each other when the conutry population is small.

# %%
# PRE-PROCESSING IF NEEDED
# YOUR CODE HERE (OPTION) 
df_copy = cleaned_df.copy()
asc_df = df_copy.sort_values(by='Total Population', ascending = True).reset_index(drop=True).loc[0:9]
asc_df
# Out:
#    Total Population  Female Population  Male Population  Birth Rate  \
# 0          258208.0           124951.0         133257.0      30.575
# 1          263841.0           127687.0         136154.0      28.240
# 2          269040.0           130164.0         138876.0      25.971
# 3          273796.0           132419.0         141377.0      24.013
# 4          278111.0           134467.0         143644.0      22.103
# 5          282507.0           136593.0         145914.0      20.539
# 6          287324.0           138960.0         148364.0      19.464
# 7          292284.0           141383.0         150901.0      18.952
# 8          297226.0           143768.0         153458.0      18.791
# 9          299097.0           140362.0         158735.0      22.900
#
#    Death Rate  Compulsory Education Dur.  Employment in Industry(%)  \
# 0       5.854                   8.913545                   21.77438
# 1       5.319                   8.913545                   21.37523
# ...

# %%
# YOUR CODE HERE
df_copy = cleaned_df.copy()
asc_df = df_copy.sort_values(by='Total Population', ascending = True).reset_index(drop=True).loc[0:9]
asc_df.drop(['Year', 'Country'], inplace=True, axis='columns')

fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(asc_df.corr(), cmap='coolwarm')
plt.show()

# %% [markdown]
# **YOUR ANSWER**
#
# Example: Is that possible to drop any features that have less effect?
# Actually, I suppose that it is possible to drop the features that have less effect. Because when plotting on the heat map correlation, it would be an empty column with no information displayed. Therefore, we hardly get any insight from the correlation map.
#
# * First impressed feature to me is **Primary completion rate**. It is proportionally developed with **Birth/ Death rate**, **employment** fraction, used in **renewable energy** and **school enrollment, primary**. However, with just primary completion, the development of the countries with small population seems to be slowed down as **GDP in USD**, **Net income from Abroad**, **life expectancy** all drop if the percentage of **Primary completion** increases.
# * Another point that I found out is that with **Unemployment**, this feature got the same development pattern with those features in **Population**. From this point, I can infer that in top smallest population, the opportunity for generating and getting job is quite limited as the population increases.

# %% [markdown]
# ## Making a question? (1.25 points)

# %% [markdown]
# After exploring the data, we have a better understanding of the data. Now let's see what questions can be answered with this data.
#
# **A possible question is:** What is the population situation of the countries on the continent today?
#
# **Answering this question will** help us to see the current population status and predictions about the future development of the labor force of the countries on the continent are under consideration.
#
# **How we answer this question**: we will consider the Average Birth Rate and Death Rate for countries across all the year.

# %% [markdown]
# ### Pre-processing

# %%
# YOUR CODE HERE (OPTION)

# %% [markdown]
# ### Analyzing to get the answer

# %% [markdown]
# Step 01: construct Average Birth Rate dataframe for each country.

# %%
# Create a new dataframe
avg_birthrate_df = pd.DataFrame()

# YOUR CODE HERE

# Find average for each country
avg_birthrate_df["Avg.Birth Rate"] = cleaned_df.groupby("Country")["Birth Rate"].mean()

# Set the index as a column - countries
avg_birthrate_df["Country"] = avg_birthrate_df.index

# Drop the index
avg_birthrate_df.reset_index(drop=True, inplace=True)

# Sort the rows based of Average Birth Rate
avg_birthrate_df.sort_values("Avg.Birth Rate", inplace=True, ascending=False)

# Display
avg_birthrate_df.head()
# Out:
#     Avg.Birth Rate      Country
# 0        42.601621  Afghanistan
# 46       36.332442  Yemen, Rep.
# 14       33.036156         Iraq
# 31       32.258621     Pakistan
# 39       30.229478   Tajikistan

# %%
# Plotting for top countries
# YOUR CODE HERE
plt.figure(figsize=(8, 5))
sns.set(style="whitegrid")
ax = sns.barplot(data=avg_birthrate_df.head(), x="Country", y= "Avg.Birth Rate")

# %% [markdown]
# Step 02: construct Average Death Rate dataframe for each country.

# %%
# Create a new dataframe
avg_deathrate_df = pd.DataFrame()

# YOUR CODE HERE

# Find average for each country
avg_deathrate_df ["Avg.Death Rate"] = cleaned_df.groupby("Country")["Death Rate"].mean()

# Set the index as a column - countries
avg_deathrate_df["Country"] = avg_deathrate_df.index

# Drop the index
avg_deathrate_df .reset_index(drop=True, inplace=True)

# Sort the rows based of Average Birth Rate
avg_deathrate_df .sort_values("Avg.Death Rate", inplace=True, ascending=False)

# Display
avg_deathrate_df .head()
# Out:
#     Avg.Death Rate             Country
# 34       14.026539  Russian Federation
# 10       11.875182             Georgia
# 0         9.438110         Afghanistan
# 28        9.436503             Myanmar
# 1         9.181610             Armenia

# %%
# Plotting for top countries
# YOUR CODE HERE
plt.figure(figsize=(8, 5))
sns.set(style="whitegrid")
ax = sns.barplot(data=avg_deathrate_df.head(), x="Country", y= "Avg.Death Rate")

# %% [markdown]
# **TODO**: Give your obervation here
# * From the birth rate and death rate data, I see that the birth rate significantly exceeds death rate in general. This suggests that the population structure in Asia is skewed towards the younger age groups.
# * Taking **Afghanistan** into consideration, the country has the highest birth rate at approximately 43. Although the death rate is less than 4.7 times that, it is still quite high compared to other countries on the continent. War, political situation could be part of potential reasons for this high death rate in the area.
# * About **Russian Federation**, this country possesses the highest death rate but birth rate is not in top compared to other countries in Asia. I make my prediction that Russia would have older age group when comparing with other Asia nations.
# * In conclusion, with displayed data, Asia now gets a population of young age. Therefore, this would be a good signal for labor force in the near future.

# %% [markdown]
# ## Making your own question 01? (1.5 points)

# %% [markdown]
# **Question :** How is employment distributed between agriculture and industry, categorized by gender ?
#
# **Answering this question will** help us to see the current employment status and predictions about the future development of the labor force of the countries in each sectors.
#
# **How we answer this question**: we will consider the Total Population, Female Population, Male Population, Employment in Industry(%), Employment in Agriculture(%), Female Employment in Agriculture(%), Female Employment in Industry(%)

# %% [markdown]
# **YOUR ANSWER HERE**

# %% [markdown]
# ### Pre-processing

# %%
# YOUR CODE HERE (OPTION)
# Create a new dataframe

# %% [markdown]
# ### Analyzing to get the answer

# %%
# YOUR CODE HERE
employment_df = pd.DataFrame()
employment_df["Total Population"] = cleaned_df.groupby("Country")["Total Population"].mean()
employment_df["Employment in Agriculture (%)"] = cleaned_df.groupby("Country")["Employment in Agriculture(%)"].mean()
employment_df["Employment in Industry (%)"] = cleaned_df.groupby("Country")["Employment in Industry(%)"].mean()

employment_df["Country"] = employment_df.index
employment_df .reset_index(drop=True, inplace=True)

employment_df.sort_values("Total Population", inplace=True, ascending=False)
employment_df.head()
# Out:
#     Total Population  Employment in Agriculture (%)  \
# 8       1.325611e+09                      38.687592
# 11      1.207484e+09                      51.549489
# 12      2.389907e+08                      38.226521
# 31      1.863866e+08                      41.748002
# 4       1.456490e+08                      48.730287
#
#     Employment in Industry (%)     Country
# 8                    25.883687       China
# 11                   20.653374       India
# 12                   19.678052   Indonesia
# 31                   22.059641    Pakistan
# 4                    16.115207  Bangladesh

# %%
plt.figure(figsize=(8, 5))
sns.set(style="whitegrid")
ax = sns.catplot(data=employment_df.head(), x="Country", y= "Employment in Agriculture (%)", kind="bar", height=5, aspect=2)

# %%
ax = sns.catplot(data=employment_df.head(), x="Country", y= "Employment in Industry (%)", kind="bar", height=5, aspect=2)

# %% [markdown]
# **Observation**
# * First of all, after visualizing the top countries in fields of Agriculture and Industry, five countries in top of Agriculture are also that in Industry, including **China**, **India**, **Indonesia**, **Pakistan** and **Bangladesh**. From my social knowledge and worked data, reason justifying for this high rate for both sectors in Asia is that all 5 countries have a large population. Hence, the proportion in financial fields is also getting higher.
# * Considering **China** and **India**, China gets highest proportion in Industry and India being highest in Agriculture, partly showing the development tendency of the two countries.

# %% [markdown]
# **Male and Female in Agriculture**

# %%
agriculture_df = pd.DataFrame()
agriculture_df["Female Employment in Agriculture"] = cleaned_df.groupby("Year")["Female Employment in Agriculture(%)"].mean()
agriculture_df["Male Employment in Agriculture"] = 100 - cleaned_df.groupby("Year")["Female Employment in Agriculture(%)"].mean()
agriculture_df["Employment in Agriculture"] = cleaned_df.groupby("Year")["Employment in Agriculture(%)"].mean()

agriculture_df["Year"] = agriculture_df.index
agriculture_df.reset_index(drop=True, inplace=True)
agriculture_df.sort_values("Employment in Agriculture", inplace=True, ascending=False)

agriculture_df.head()
# Out:
#    Female Employment in Agriculture  Male Employment in Agriculture  \
# 0                         39.226422                       60.773578
# 1                         38.834904                       61.165096
# 3                         38.364470                       61.635530
# 2                         38.383425                       61.616575
# 4                         38.133055                       61.866945
#
#    Employment in Agriculture  Year
# 0                  35.952202  1995
# 1                  35.462565  1996
# 3                  35.111517  1998
# 2                  35.043402  1997
# 4                  34.880879  1999

# %%
# use line plot to show the trend of employment in agriculture
plt.figure(figsize=(8, 5))
sns.set(style="whitegrid")
ax = sns.lineplot(data=agriculture_df, x="Year", y= "Employment in Agriculture", marker='o', label ="Employment in Agriculture")
ax = sns.lineplot(data=agriculture_df, x="Year", y= "Female Employment in Agriculture", marker='o', label="Female Employment")
ax = sns.lineplot(data=agriculture_df, x="Year", y= "Male Employment in Agriculture", marker='o', label="Male Employment")
#how to annotate the plot

# %%
industry_df = pd.DataFrame()
industry_df["Female Employment in Industry"] = cleaned_df.groupby("Year")["Female Employment in Industry(%)"].mean()
industry_df["Male Employment in Industry"] = 100 - cleaned_df.groupby("Year")["Female Employment in Industry(%)"].mean()
industry_df["Employment in Industry"] = cleaned_df.groupby("Year")["Employment in Industry(%)"].mean()

industry_df["Year"] = industry_df.index
industry_df.reset_index(drop=True, inplace=True)
industry_df.sort_values("Employment in Industry", inplace=True, ascending=False)

industry_df.head()
# Out:
#     Female Employment in Industry  Male Employment in Industry  \
# 26                      13.437369                    86.562631
# 25                      13.711143                    86.288857
# 23                      13.279571                    86.720429
# 24                      13.399046                    86.600954
# 22                      13.115487                    86.884513
#
#     Employment in Industry  Year
# 26               23.550478  2021
# 25               23.167988  2020
# 23               23.073502  2018
# 24               23.012913  2019
# 22               22.795060  2017

# %%
plt.figure(figsize=(8, 5))
sns.set(style="whitegrid")
ax = sns.lineplot(data=industry_df, x="Year", y= "Employment in Industry")
ax = sns.lineplot(data=industry_df, x="Year", y= "Female Employment in Industry", label = "Female")
ax = sns.lineplot(data=industry_df, x="Year", y= "Male Employment in Industry", label = "Male")

# %% [markdown]
# **OBSERVATION AND CONCLUSION**
#
# * From the graph employment in Agriculture, from 1995 to 2020, the general development tendency of the fields is a downward pattern, falling from around 35% in 1995 to nearly 20% in 2020. This is a signal for Economic Restructuring in the century 21th, moving from Agriculture to Industry and Service.
# * The pattern for Industry development over 25 years (1995-2020) seems to remain stable with quite low proportion, over 23% in Asia area. Although at first, the portion in Industry is pretty low in comparison with Agriculture, Industry still plays an important and prequisite role in the economy.
# * Taking about labor force - division of labour, male take the lion share in both sectors, Agriculture and Industry. In term of Agriculture, male and female have opposite direction in work force development with a huge distance. Male engage in Agriculture work more and more with more than 75% in 2020, female only get nearly 23%. However, in late 2020, the overal labour force in Agriculture seemed to get a small upsurge - a positive signal for the regrowth in the sector. However, the upward pattern is meaning with female, while male have a tendency of less interest in field since 2020. About Industry, male and female all got a plateau trend for division of labor over the years, but with a huge gap. In such a heavy fields, female work force only take more than 12%, male - more than 85%.
# * In conclusion, the economic structure of Asia is undergoing significant changes, transitioning from an agricultural-based economy to an industrial one. Furthermore, men continue to play a dominant role in the labor market. While the participation of women in agriculture is decreasing, there is potential for their increased presence in the industrial and service sectors.

# %% [markdown]
# ## Making your own question 02? (1.5 points)

# %% [markdown]
# **Question :** How is gender distributed over the time ?
#
# **Answering this question will** help us to see the current population distribution status and also understand more about current thinking on gender in Asia.
#
# **How we answer this question**: we will compare the data on Female Population and Male Population over the time.

# %% [markdown]
# **YOUR ANSWER HERE**

# %% [markdown]
# ### Pre-processing

# %%
# YOUR CODE HERE (OPTION)

# %% [markdown]
# ### Analyzing to get the answer

# %%
# YOUR CODE HERE
population_df = pd.DataFrame()
population_df["Total Population"] = cleaned_df.groupby("Year")["Total Population"].sum()
population_df["Female Population"] = cleaned_df.groupby("Year")["Female Population"].sum()
population_df["Male Population"] = cleaned_df.groupby("Year")["Male Population"].sum()

population_df["Year"] = population_df.index
population_df.reset_index(drop=True, inplace=True)
population_df.sort_values("Total Population", inplace=True, ascending=False)

population_df.head()
# Out:
#     Total Population  Female Population  Male Population  Year
# 27      4.816520e+09       2.371572e+09     2.444947e+09  2022
# 26      4.787918e+09       2.356516e+09     2.431402e+09  2021
# 25      4.758096e+09       2.340743e+09     2.417353e+09  2020
# 24      4.722602e+09       2.322306e+09     2.400296e+09  2019
# 23      4.683152e+09       2.302204e+09     2.380949e+09  2018

# %%
plt.figure(figsize=(8, 5))
sns.set(style="whitegrid")
ax = sns.lineplot(data=population_df, x="Year", y= "Total Population", label='Total Population')
ax = sns.lineplot(data=population_df, x="Year", y="Female Population", label="Female Population")
ax = sns.lineplot(data=population_df, x="Year", y="Male Population", label="Male Population")

# %% [markdown]
# **OBSERVATION AND CONCLUSION**
#
# * In general, Asia's population is growing rapidly, following an upward linear trend, with both men and women experiencing similar growth rates. While the lines representing men and women appear parallel, the male population is larger.
#
# * It seems that Asia's population is still growing for both genders, but at a slower pace. According to natural demographics, the sex ratio should be approximately 1:1. However, the graph displays a gap, indicating that biases towards favoring the birth of male babies over female babies still persist.

# %% [markdown]
# ## Making your own question 03? (1.5 points)

# %% [markdown]
# **Question :** How is birth rate relate with Male life expectancy and Female life expectancy?
#
# **Answering this question will** help us to assess health problem involving in human life expectancy with birth rate so that we could make a better decision for child birth with ensured health.
#
# **How we answer this question**: we will consider the Average Birth Rate and Death Rate for countries across all the year.

# %% [markdown]
# **YOUR ANSWER HERE**

# %% [markdown]
# ### Pre-processing

# %%
# YOUR CODE HERE (OPTION)

# %% [markdown]
# ### Analyzing to get the answer

# %% [markdown]
# ### To get insight into this problem, I will devide into 2 groups: Top 15 Largest Population and Top 15 Smallest Population to get more objective opinion.

# %% [markdown]
# **TOP 15 LARGEST POPULATION**

# %%
life_expectancy_1 = pd.DataFrame()
life_expectancy_1["Female life expectancy"] = des_df["Female life expectancy "].loc[0:15]
life_expectancy_1["Male life expectancy"] = des_df["Male life expectancy"].loc[0:15]
life_expectancy_1["Birth rate"] = des_df["Birth Rate"].loc[0:15]

life_expectancy_1.head()
# Out:
#    Female life expectancy  Male life expectancy  Birth rate
# 0               74.080759             68.719252   20.700378
# 1               81.155000             75.463000    7.520000
# 2               74.080759             68.719252   20.700378
# 3               81.058000             75.305000    8.520000
# 4               80.816000             75.298000   10.410000

# %%
#show correlation
fig, ax = plt.subplots(figsize=(8,8))
sns.heatmap(life_expectancy_1.corr(), cmap='coolwarm', center=0,ax=ax)
plt.show()

# %% [markdown]
# **TOP 15 SMALLEST POPULATION**

# %%
life_expectancy_2 = pd.DataFrame()
life_expectancy_2["Female life expectancy"] = asc_df["Female life expectancy "].loc[0:15]
life_expectancy_2["Male life expectancy"] = asc_df["Male life expectancy"].loc[0:15]
life_expectancy_2["Birth rate"] = asc_df["Birth Rate"].loc[0:15]

life_expectancy_2.head()
# Out:
#    Female life expectancy  Male life expectancy  Birth rate
# 0                  68.435                66.723      30.575
# 1                  69.451                68.091      28.240
# 2                  70.019                68.582      25.971
# 3                  70.323                68.955      24.013
# 4                  70.975                69.374      22.103

# %%
fig, ax = plt.subplots(figsize=(8,8))
sns.heatmap(life_expectancy_2.corr(), cmap='coolwarm', center=0,ax=ax)
plt.show()

# %% [markdown]
# **OBSERVATION AND CONCLUSION**
# * After analyzing two groups, one with the largest population and the other with the smallest, it’s clear that both groups exhibit a similar correlation pattern among birth rate, male life expectancy, and female life expectancy. There is a positive correlation between male and female life expectancy, suggesting that both genders may experience similar living conditions.
#
# * However, when examining the correlation between birth rate and life expectancy for both genders, a negative correlation emerges. A high birth rate often implies a larger number of children per couple. This can adversely affect the health of mothers due to the physical demands of pregnancy and the subsequent time and energy spent raising children. Men are also affected as they are typically seen as the primary earners, and having more children means they have to work harder to maintain the family’s standard of living. Consequently, **a higher birth rate negatively impacts human life expectancy**.

# %% [markdown]
# ## Making your own question 04? (1.5 points)

# %% [markdown]
# **Question :** What is the correlation among GDP, employment in industry and employment in agriculture?
#
# **Answering this question will** help us to see the current population distribution status and also understand more about current thinking on gender in Asia.
#
# **How we answer this question**: we will consider the Average Birth Rate and Death Rate for countries across all the year.

# %% [markdown]
# **YOUR ANSWER HERE**

# %% [markdown]
# ### Pre-processing

# %%
employment_top_GDP = pd.DataFrame()
employment_top_GDP["GDP in USD"] = cleaned_df.groupby("Country")["GDP in USD"].mean().sort_values(ascending=False)
employment_top_GDP["Employment in Agriculture"] = cleaned_df.groupby("Country")["Employment in Agriculture(%)"].mean()
employment_top_GDP["Employment in Industry"] = cleaned_df.groupby("Country")["Employment in Industry(%)"].mean()
employment_top_GDP = employment_top_GDP.head(15)
employment_top_GDP
# Out:
#                              GDP in USD  Employment in Agriculture  \
# Country
# China                      6.645461e+12                  38.687592
# Japan                      4.937182e+12                   5.067152
# India                      1.477519e+12                  51.549489
# Russian Federation         1.171268e+12                   9.868139
# Korea, Rep.                1.094419e+12                   8.473972
# Indonesia                  6.046269e+11                  38.226521
# Turkey                     5.945342e+11                  27.725758
# Saudi Arabia               4.927959e+11                   6.818156
# Korea, Dem. People’s Rep.  4.457851e+11                  47.855084
# Iran, Islamic Rep.         3.070278e+11                  20.044930
# Thailand                   3.020139e+11                  40.560831
# United Arab Emirates       2.601459e+11                   5.809127
# Israel                     2.405287e+11                   2.627588
# ...

# %%
employment_bottom_GDP = pd.DataFrame()
employment_bottom_GDP["GDP in USD"] = cleaned_df.groupby("Country")["GDP in USD"].mean().sort_values(ascending=True)
employment_bottom_GDP["Employment in Agriculture"] = cleaned_df.groupby("Country")["Employment in Agriculture(%)"].mean()
employment_bottom_GDP["Employment in Industry"] = cleaned_df.groupby("Country")["Employment in Industry(%)"].mean()
employment_bottom_GDP = employment_bottom_GDP.head(15)
employment_bottom_GDP
# Out:
#                      GDP in USD  Employment in Agriculture  \
# Country
# Maldives           2.539894e+09                  14.113095
# Kyrgyz Republic    4.782086e+09                  35.533055
# Tajikistan         4.828190e+09                  52.123729
# Mongolia           6.989522e+09                  37.715719
# Armenia            7.839214e+09                  39.417187
# Lao PDR            8.165203e+09                  71.188259
# Georgia            1.076905e+10                  47.564243
# Brunei Darussalam  1.095040e+10                   2.400576
# Cambodia           1.238073e+10                  56.388340
# Nepal              1.672508e+10                  67.655964
# Bhutan             1.716854e+10                  61.138863
# Cyprus             1.975539e+10                   5.603588
# Bahrain            2.258974e+10                   2.305004
# Jordan             2.433024e+10                   4.706545
# Myanmar            3.398158e+10                  53.895807
#
# ...

# %% [markdown]
# ### Analyzing to get the answer

# %%
fig, ax = plt.subplots(figsize=(7,7))
sns.heatmap(employment_top_GDP.corr(), cmap='RdBu',center=0,ax=ax, annot=True)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(7,7))
sns.heatmap(employment_bottom_GDP.corr(), cmap='RdBu',center=0,ax=ax, annot=True)
plt.show()

# %% [markdown]
# **OBSERVATION AND CONCLUSION**
#
# * After investigating on two group of highest GDP and lowest GDP, it appears that the group of countries with the lowest GDP has a stronger correlation among three sectors: GDP in USD, Employment in Agriculture, and Employment in Industry.
# * In both groups, there is a significant negative correlation between Employment in Agriculture and Employment in Industry. If the proportion of employment in Agriculture increases, the proportion in Industry decreases significantly, and vice versa.
# * However, the correlation between GDP and Agriculture/Industry is relatively weak, although it’s believed to have some impacts.
#     * In the group with the highest GDP, both Agriculture and Industry have a positive impact on the GDP, with correlation coefficients of 0.16 and 0.19 respectively.
#     * Interestingly, in the group of countries with low GDP, a large proportion of employment in agriculture does not positively impact the overall GDP. This could signal a need for economic transition towards other sectors for accelerated development.
# **Prediction** :
# * If the current trends continue, we might see a further decrease in the Agriculture sector in countries with high GDP as the Industry sector continues to grow.
# * In countries with low GDP, if the large ratio of agriculture continues to have a negative impact on the GDP, these countries might need to transition their economies towards other sectors for faster development. This could lead to significant socio-economic changes in these countries in the future.
# * The drawn conclusion that employment rate of the two sectors has a relatively low impact on GDP, it suggests that others factors are playing a more significant role in driving the economic output. They could be as follows, according to my knowledge:
#     * The productivity in working environment is still low so it requires more improvement.
#     * Lack of effective investment. To fix this, the nation with low GDP should open to call for more investment from abroad and private organization.
#     * Technology and Innovation: It is widely acknowledged that technological advancements and innovation is the key factors contributing to the development of new products, services at all sides.
#     * There would be many more factors. However, the forementioned factors would be the core issues to pay attention to first - I suppose.

# %% [markdown]
# ## Making your own question 05? (1.5 points)

# %% [markdown]
# **Question :** Is that true if higher employment rate would lead to higher GDP?
#
# **Answering this question will** help us to see the current population distribution status and also understand more about current thinking on gender in Asia.
#
# **How we answer this question**: we will consider the Average Birth Rate and Death Rate for countries across all the year.

# %% [markdown]
# **YOUR ANSWER HERE**

# %% [markdown]
# ### Pre-processing

# %%
employment_GDP = pd.DataFrame()
employment_GDP["GDP in USD"] = cleaned_df.groupby("Country")["GDP in USD"].mean()
employment_GDP["Employment rate"] = 100 - cleaned_df.groupby("Country")["Unemployment(%)"].mean()
employment_GDP.dropna(inplace=True)
employment_GDP.sort_values("GDP in USD", inplace=True, ascending=False)
employment_GDP
# Out:
#                              GDP in USD  Employment rate
# Country
# China                      6.645461e+12        95.760857
# Japan                      4.937182e+12        96.086393
# India                      1.477519e+12        92.018679
# Russian Federation         1.171268e+12        92.597658
# Korea, Rep.                1.094419e+12        96.521857
# Indonesia                  6.046269e+11        94.593893
# Turkey                     5.945342e+11        90.335714
# Saudi Arabia               4.927959e+11        94.400714
# Korea, Dem. People’s Rep.  4.457851e+11        97.104607
# Iran, Islamic Rep.         3.070278e+11        88.736714
# Thailand                   3.020139e+11        98.752000
# United Arab Emirates       2.601459e+11        97.541036
# Israel                     2.405287e+11        91.832321
# Singapore                  2.211486e+11        95.898607
# Malaysia                   2.209702e+11        96.665143
# ...

# %% [markdown]
# ### Analyzing to get the answer

# %%
#use scatter plot to show the correlation
plt.figure(figsize=(7,7))
sns.scatterplot(data=employment_GDP, x="GDP in USD", y="Employment rate")
plt.show()

# %% [markdown]
# **OBSERVATION**
# * From the scatter plot graph, it’s evident that most Asian countries, regardless of their employment rate, have a GDP ranging from 0 to 1 trillion USD. For instance, Bhutan, despite having an high employment rate of nearly 97%, has a GDP of just over 1 billion USD. This could be attributed to Bhutan’s small population or the workforce’s effectiveness not yet meeting the standard.
# * On the other hand, China and Japan, the two countries with the highest GDP, both have high employment rates of approximately 96%. Their GDPs, standing at 6.6 trillion USD for China and 5 trillion USD for Japan, are reflective of their workforce’s value. These figures are quite impressive compared to the rest of Asia, outpacing other countries by nearly 4 trillion USD in GDP.
#     * It is universally acknowledged that both China and Japan are powerful countries in the world. The two countries is reknown for hard working, responsible citizens, who are dedicated to their duties and have a strong commitment to learning and exploring science and technology. This contributes significantly to their countries’ development and the standard of living.

# %% [markdown]
# **CONCLUSION**
# * It’s not necessarily true that a higher employment rate would lead to a higher GDP. While China and Japan, which have high employment rates of approximately 96%, also have high GDPs, this is not the case for all countries. For instance, Bhutan has a similarly high employment rate of nearly 97%, but its GDP is just over 1 billion USD.
#
# * This suggests that while employment rate can contribute to a country’s GDP, it’s not the only factor. Other elements, such as the size of the population, the effectiveness of the workforce, and the level of technological advancement, also play significant roles in a country’s economic performance. Therefore, it’s important to consider these factors when analyzing the relationship between employment rate and GDP.
