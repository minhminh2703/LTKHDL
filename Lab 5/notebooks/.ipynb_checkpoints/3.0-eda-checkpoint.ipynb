# %% [markdown]
# <div style="text-align: center; background-color: #559cff; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 20px; font-size: 40px; font-weight: bold; border-radius: 0 0 0 0; box-shadow: 0px 6px 8px rgba(0, 0, 0, 0.2);">
#   Lab 02 - Introduction To Data Science @ FIT-HCMUS, VNU-HCM 📌
# </div>

# %% [markdown]
# <div style="text-align: center; background-color: #b1d1ff; font-family: 'Trebuchet MS', Arial, sans-serif; color: white; padding: 20px; font-size: 40px; font-weight: bold; border-radius: 0 0 0 0; box-shadow: 0px 6px 8px rgba(0, 0, 0, 0.2);">
#   Stage 3.0 - Exploratory data analysis
# </div>

# %% [markdown]
# ## Import

# %%
import os
import sys

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# YOUR CODE HERE (OPTION) 
# If you need other libraries, you can import them here
import seaborn as sns

# %% [markdown]
# ## Exploring your data

# %% [markdown]
# ### Read cleaned data from file (0.25 points)

# %% [markdown]
# We can now use the cleaned dataset for analysis. Thus, we first read the CSV files we created in the previous pre-processing task.

# %%
# YOUR CODE HERE
cleaned_df = pd.read_csv("../data/processed/21127528_asia_processed.csv")

# %%
# TEST
cleaned_df.head()
# Out:
#    Total Population  Female Population  Male Population  Birth Rate  \
# 0        41128771.0         20362329.0       20766442.0         NaN
# 1        40099462.0         19844584.0       20254878.0      35.842
# 2        38972230.0         19279929.0       19692301.0      36.051
# 3        37769499.0         18679090.0       19090409.0      36.466
# 4        36686784.0         18136922.0       18549862.0      36.927
#
#    Death Rate  Compulsory Education Dur.  Employment in Industry(%)  \
# 0         NaN                        9.0                        NaN
# 1       7.344                        9.0                        NaN
# 2       7.113                        9.0                   18.48131
# 3       6.791                        9.0                   18.33941
# 4       6.981                        9.0                   18.12015
#
#    Employment in Agriculture(%)  Female Employment in Agriculture(%)  \
# 0                           NaN                                  NaN
# ...

# %%
# TEST
cleaned_df.shape
# Out:
# (1316, 26)

# %% [markdown]
# ### Numerical analysis using descriptive statistics (0.25 points)

# %% [markdown]
# Descriptive statistics show the characteristics of numerical features. It shows us the information such as:
# - The mean (and you can go further with advanced techiques as Arithmetic mean, Geometric mean, Harmonic mean)
# - The median
# - The mode
# - Quantiles (Quartiles, Percentiles, Deciles, Crocodiles?)
# - Range and IQR (Interquartile Range) (you might find that its relation to box plots)
# - Variance and Standard deviation (std dev)
# - Coefficient of Variation
# - Skewness
# - Kurtosis
# - Standard Error (of the sample mean)
# - Moments
# - Covariance and Correlation
#
# Due the scope of this lab, you just need to use basic function of Pandas to calculate basic descriptive statistics information and give insights from it.

# %%
df_copy = cleaned_df.drop(['Year', 'Country'], axis='columns')

# YOUR CODE HERE
df_copy.describe()
# Out:
#        Total Population  Female Population  Male Population   Birth Rate  \
# count      1.316000e+03       1.316000e+03     1.316000e+03  1269.000000
# mean       9.020217e+07       4.433594e+07     4.586623e+07    20.700378
# std        2.549317e+08       1.240024e+08     1.309465e+08     7.833438
# min        2.582080e+05       1.249510e+05     1.332570e+05     5.100000
# 25%        4.382818e+06       2.121473e+06     2.311564e+06    15.051000
# 50%        1.822701e+07       9.013542e+06     9.061772e+06    19.841000
# 75%        6.135766e+07       3.051728e+07     3.080141e+07    24.649000
# max        1.417173e+09       6.915285e+08     7.311805e+08    52.073000
#
#         Death Rate  Compulsory Education Dur.  Employment in Industry(%)  \
# count  1269.000000                1041.000000                1267.000000
# mean      6.343087                   8.913545                  21.368640
# std       2.718865                   2.021095                   7.901133
# ...

# %% [markdown]
# **TODO**: Give your obervation here
#
# * From the given dataframe, at the **count** row, it is observed that there is only 3 columns tagged *Total Population*, *Female Population* and *Male Population* having enough data on total 1316 lines. Most of features don't fill up all 1316 rows, in terms of **literacy rate**, the data only lie in 267/1316 rows.
# * At the **mean** row, it's clearly that birth rate is quite low in Asia with just 20.7. It's also shown that the average portion employment of women in agriculture is relative high comparing with industrial field.
# * I will have some comment on the economical development of Asia based on **mean** and **std (standard deviation)** index and the two features taken into consideration are **GDP in USD** and **Net income from Abroad**. The table statistictis show us:
#     * On average, the GDP is around 445.78 billion USD - central value of data. In addition, the standard deviation is quite high, about nearly 1.48 trillion USD; this number tells us a wide disperation of data. From both of the feature number, it is concluded that from the data point of mean value, the GPD in USD data across Asia vary in a large range that up to trillions of USD.
#     * In term of **Net income from Abroad**, we can observe that there exists negative values in **Mean**. This index indicate that on average, countries in Asia experience net loss; it's synonymous with the fact that expenses spent on operation, factory or investment outweight the profit produced in the net income abroad. **Std** of approximately 25.35 billion indicates a high variability in the net from abroad. In columns **Min** and **Max** with -192.8 billion and 242.99 billion respectively, such a high variability might provide a potential prediction for significant outliers in the data, which present heavy impact on the overall performance for the economical operation in Asia.
# * The appearance of number 0 in the statistic table all lies in the issue of energy consumption including **Renewable Energy Consumption** and **Fossil Fuel Comsumption**. This indicates that there exists third-world country have no renewable energy consumption in a particular year, while existing developed country in Asia that consume 0% fossil fuel for energy in a year but using renewable ones or maybe nuclear power instead.
#
#
#
#
# ...

# %% [markdown]
# ### Describe the correlation between features in the dataset (0.75 points)

# %% [markdown]
# Considering the available features within the training dataset, we want to identify and analyse the relationships between them, and then determine which features within the dataset significantly contribute to our solution goal. By using calculation and visualisation, Python allows us to create a correlation matrix, which is a table that represents the correlation coefficients between different variables.

# %% [markdown]
# Now let's make a correlation matrix, then visualize it, and describe what insights you observed?

# %%
# PRE-PROCESSING IF NEEDED
# YOUR CODE HERE (OPTION)

# %%
# YOUR CODE HERE
# create a copy
df_copy = cleaned_df.copy()

# Exclude the categorical features from the matrix
df_copy.drop(['Year', 'Country'], inplace=True, axis='columns')

# plot a correlation matrix
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(df_copy.corr(), cmap='RdBu', center=0,ax=ax)
plt.show()

# %% [markdown]
# * From the correlation map, **National income per Capita**, **Net income from Abroad** and **Compulsory Education Dur.** seem to have no strong relation with other features.
# * Concern relation in employment, there is a tight relationship between two sectors: agriculture and industry. It can be seen that employments in agriculture (including female employment) and industry are in inverse relation.This implies that an increase in the proportion of employment in industry will lead to a decrease in the agricultural workforce.
# * Besides that, in the group concluding **Electric Power Consumption**, **Renewable Energy Consumption**, **Fossil Fuel Consumption**, **Male life expectancy** and **Female life expectancy**, this area is highlighted with dark blue except for **Renewable Energy Consumption**. Dark blue show that correlation coefficient is near with value 1 so that these features have positive influence on each other. **Renewable Energy Consumption**, on the other hand, is colored in red showing inverse relation with other features in the mentioned group. It is reasonably understood that the more we use renewable energy, the good effect on different fields is also clearly described, - fossil fuel and electric power comsumed drop. However, its relationship with life expectancy is quite weak.
# * A remarkable connection is witnessed among the **(Female) Employment in Agriculture** with the group concluding **Electric Power Consumption**, **Renewable Energy Consumption**, **Fossil Fuel Consumption**, **Male life expectancy** and **Female life expectancy**. The development of Agriculture company with the growth of renewable energy consumption; but somehow make a contribution to the decrease in portion of fossil fuel, deployed electric power, espcially male/ female life expectancy. I suppose that due to the poisonous working environment with pesticide, fertilize or heavy sun ray, human life expectancy is shortened greatly.

# %% [markdown]
# **Question 01**: How does the correlation between features change in the top 10 countries with the LARGEST population?
#
# When we have an answer for this question, we might see how features interaction with each other when the conutry population is large.

# %%
# PRE-PROCESSING IF NEEDED
# YOUR CODE HERE (OPTION)
df_copy = cleaned_df.copy()
des_df = df_copy.sort_values(by='Total Population', ascending = False).reset_index(drop=True).loc[0:9]
des_df
# Out:
#    Total Population  Female Population  Male Population  Birth Rate  \
# 0      1.417173e+09        685992675.0      731180498.0         NaN
# 1      1.412360e+09        691219627.0      721140373.0       7.520
# 2      1.412175e+09        691528501.0      720646499.0         NaN
# 3      1.411100e+09        690171847.0      720928153.0       8.520
# 4      1.407745e+09        688179990.0      719565010.0      10.410
# 5      1.407564e+09        681060413.0      726503429.0      16.419
# 6      1.402760e+09        685468977.0      717291023.0      10.860
# 7      1.396387e+09        675389679.0      720997448.0      16.572
# 8      1.396215e+09        682006802.0      714208198.0      12.640
# 9      1.387790e+09        677689913.0      710100087.0      13.570
#
#    Death Rate  Compulsory Education Dur.  Employment in Industry(%)  \
# 0         NaN                        8.0                        NaN
# 1       7.180                        9.0                   28.24155
# ...

# %%
# YOUR CODE HERE
# plot a correlation matrix

df_copy = cleaned_df.copy()
des_df = df_copy.sort_values(by='Total Population', ascending = False).reset_index(drop=True).loc[0:9]
des_df.drop(['Year', 'Country','Electric Power Consumption(kWH per capita)','Fossil Fuel Consumption (%)','Primary completion rate'], inplace=True, axis='columns')

fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(des_df.corr(), cmap='RdBu',center=0,ax=ax)
plt.show()

# %% [markdown]
# * After printing out the dataframe, I observe that there exists 3 columns that are filled null value : **Electric Power Consumption(kWH per capita)**, **Fossil Fuel Consumption (%)**, **Primary completion rate**. Therefore, there is no point in keeping 3 columns as they cant help us to bring out any useful analysis on the correlation.

# %% [markdown]
# **YOUR ANSWER**

# %% [markdown]
# * After plotting data with heat map, I found out that in top 10 countries with largest population, almost any fields have strong connection with each others, both positively and negatively.
# * To talk about the least influence, it lies in 2 features **Net Income from Abroad**, **School enronment, Primary**.
# * With inverse correlation, **Female/Employment in Agriculture** possess the most impact. Increasing work force in agriculture leads to the intensive drop in the portion of other majors like industry; especially in **GDP in USD**, educational issues: **Compulsory Education Dur.**, **School enrollment, tertiary** and **Literacy rate** and human life expectancy.

# %% [markdown]
# **Question 02**: How does the correlation between features change in the top 10 countries with the SMALLEST population?
#
# When we have an answer for this question, we might see how features interaction with each other when the conutry population is small.

# %%
# PRE-PROCESSING IF NEEDED
# YOUR CODE HERE (OPTION) 
df_copy = cleaned_df.copy()
asc_df = df_copy.sort_values(by='Total Population', ascending = True).reset_index(drop=True).loc[0:9]
asc_df
# Out:
#    Total Population  Female Population  Male Population  Birth Rate  \
# 0          258208.0           124951.0         133257.0      30.575
# 1          263841.0           127687.0         136154.0      28.240
# 2          269040.0           130164.0         138876.0      25.971
# 3          273796.0           132419.0         141377.0      24.013
# 4          278111.0           134467.0         143644.0      22.103
# 5          282507.0           136593.0         145914.0      20.539
# 6          287324.0           138960.0         148364.0      19.464
# 7          292284.0           141383.0         150901.0      18.952
# 8          297226.0           143768.0         153458.0      18.791
# 9          299097.0           140362.0         158735.0      22.900
#
#    Death Rate  Compulsory Education Dur.  Employment in Industry(%)  \
# 0       5.854                        NaN                   21.77438
# 1       5.319                        NaN                   21.37523
# ...

# %%
# YOUR CODE HERE
df_copy = cleaned_df.copy()
asc_df = df_copy.sort_values(by='Total Population', ascending = True).reset_index(drop=True).loc[0:9]
asc_df.drop(['Year', 'Country', 'National Income per Capita', 
             'Agriculture value added(in USD)', 'Electric Power Consumption(kWH per capita)',
             'Fossil Fuel Consumption (%)','School enrollment, tertiary','Literacy rate','Compulsory Education Dur.'], inplace=True, axis='columns')

fig, ax = plt.subplots(figsize=(10,10))
# sns.heatmap(asc_df.corr(), cmap='coolwarm',center=0,ax=ax)
sns.heatmap(asc_df.corr(), cmap='coolwarm')
plt.show()

# %% [markdown]
# **YOUR ANSWER**
#
# Example: Is that possible to drop any features that have less effect?
# Actually, I suppose that it is possible to drop the features that have less effect. Because when plotting on the heat map correlation, it would be an empty column with no information displayed. Therefore, we hardly get any insight from the correlation map. In this situation, I decided to drop about 6 features for better understandings.
# * First impressed feature to me is **Primary completion rate**. It is proportionally developed with **Birth/ Death rate**, **employment** fraction, used in **renewable energy** and **school enrollment, primary**. However, with just primary completion, the development of the countries with small population seems to be slowed down as **GDP in USD**, **Net income from Abroad**, **life expectancy** all drop if the percentage of **Primary completion** increases.
# * Another point that I found out is that with **Unemployment**, this feature got the same development pattern with those features in **Population**. From this point, I can infer that in top smallest population, the opportunity for generating and getting job is quite limited as the population increases.

# %% [markdown]
# ## Making a question? (1.25 points)

# %% [markdown]
# After exploring the data, we have a better understanding of the data. Now let's see what questions can be answered with this data.
#
# **A possible question is:** What is the population situation of the countries on the continent today?
#
# **Answering this question will** help us to see the current population status and predictions about the future development of the labor force of the countries on the continent are under consideration.
#
# **How we answer this question**: we will consider the Average Birth Rate and Death Rate for countries across all the year.

# %% [markdown]
# ### Pre-processing

# %%
# YOUR CODE HERE (OPTION)

# %% [markdown]
# ### Analyzing to get the answer

# %% [markdown]
# Step 01: construct Average Birth Rate dataframe for each country.

# %%
# Create a new dataframe
avg_birthrate_df = pd.DataFrame()

# YOUR CODE HERE

# Find average for each country
avg_birthrate_df["Avg.Birth Rate"] = cleaned_df.groupby("Country")["Birth Rate"].mean()

# Set the index as a column - countries
avg_birthrate_df["Country"] = avg_birthrate_df.index

# Drop the index
avg_birthrate_df.reset_index(drop=True, inplace=True)

# Sort the rows based of Average Birth Rate
avg_birthrate_df.sort_values("Avg.Birth Rate", inplace=True, ascending=False)

# Display
avg_birthrate_df.head()
# Out:
#     Avg.Birth Rate      Country
# 0        43.412778  Afghanistan
# 46       36.911407  Yemen, Rep.
# 14       33.493037         Iraq
# 31       32.686704     Pakistan
# 39       30.582407   Tajikistan

# %%
# Plotting for top countries
# YOUR CODE HERE
plt.figure(figsize=(8, 5))
sns.set(style="whitegrid")
ax = sns.barplot(data=avg_birthrate_df.head(), x="Country", y= "Avg.Birth Rate")

# %% [markdown]
# Step 02: construct Average Death Rate dataframe for each country.

# %%
# Create a new dataframe
avg_deathrate_df = pd.DataFrame()

# YOUR CODE HERE

# Find average for each country
avg_deathrate_df ["Avg.Death Rate"] = cleaned_df.groupby("Country")["Death Rate"].mean()

# Set the index as a column - countries
avg_deathrate_df["Country"] = avg_deathrate_df.index

# Drop the index
avg_deathrate_df .reset_index(drop=True, inplace=True)

# Sort the rows based of Average Birth Rate
avg_deathrate_df .sort_values("Avg.Death Rate", inplace=True, ascending=False)

# Display
avg_deathrate_df .head()
# Out:
#     Avg.Death Rate             Country
# 34       14.311111  Russian Federation
# 10       12.080074             Georgia
# 0         9.552741         Afghanistan
# 28        9.551074             Myanmar
# 1         9.286741             Armenia

# %%
# Plotting for top countries
# YOUR CODE HERE
plt.figure(figsize=(8, 5))
sns.set(style="whitegrid")
ax = sns.barplot(data=avg_deathrate_df.head(), x="Country", y= "Avg.Death Rate")

# %% [markdown]
# **TODO**: Give your obervation here
# * From the birth rate and death rate data, I see that the birth rate significantly exceeds death rate in general. This suggests that the population structure in Asia is skewed towards the younger age groups.
# * Taking **Afghanistan** into consideration, the country has the highest birth rate at approximately 43. Although the death rate is less than 4.7 times that, it is still quite high compared to other countries on the continent. War, political situation could be part of potential reasons for this high death rate in the area.
# * About **Russian Federation**, this country possesses the hightest death rate but birth rate is not in top compared to other countries in Asia. I make my prediction that Russia would have older age group when comparing with other Asia nations.
# * In conclusion, with displayed data, Asia now gets a population of young age. Therefore, this would be a good signal for labor force in the near future.

# %% [markdown]
# ## Making your own question 01? (1.5 points)

# %% [markdown]
# **Question :** How is employment distributed between agriculture and industry, categorized by gender ?
#
# **Answering this question will** help us to see the current employment status and predictions about the future development of the labor force of the countries in each sectors.
#
# **How we answer this question**: we will consider the Average Birth Rate and Death Rate for countries across all the year.

# %% [markdown]
# **YOUR ANSWER HERE**

# %% [markdown]
# ### Pre-processing

# %%
# YOUR CODE HERE (OPTION)

# %% [markdown]
# ### Analyzing to get the answer

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Making your own question 02? (1.5 points)

# %% [markdown]
# **Question :** How is gender distributed over the time ?
#
# **Answering this question will** help us to see the current population distribution status and also understand more about current thinking on gender in Asia.
#
# **How we answer this question**: we will consider the Average Birth Rate and Death Rate for countries across all the year.

# %% [markdown]
# **YOUR ANSWER HERE**

# %% [markdown]
# ### Pre-processing

# %%
# YOUR CODE HERE (OPTION)

# %% [markdown]
# ### Analyzing to get the answer

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Making your own question 03? (1.5 points)

# %% [markdown]
# **Question :** How is gender distributed over the time ?
#
# **Answering this question will** help us to see the current population distribution status and also understand more about current thinking on gender in Asia.
#
# **How we answer this question**: we will consider the Average Birth Rate and Death Rate for countries across all the year.

# %% [markdown]
# **YOUR ANSWER HERE**

# %% [markdown]
# ### Pre-processing

# %% [markdown]
# ### Analyzing to get the answer

# %% [markdown]
# ## Making your own question 04? (1.5 points)

# %% [markdown]
# **Question :** How is gender distributed over the time ?
#
# **Answering this question will** help us to see the current population distribution status and also understand more about current thinking on gender in Asia.
#
# **How we answer this question**: we will consider the Average Birth Rate and Death Rate for countries across all the year.

# %% [markdown]
# **YOUR ANSWER HERE**

# %% [markdown]
# ### Pre-processing

# %% [markdown]
# ### Analyzing to get the answer

# %% [markdown]
# ## Making your own question 05? (1.5 points)

# %% [markdown]
# **Question :** How is gender distributed over the time ?
#
# **Answering this question will** help us to see the current population distribution status and also understand more about current thinking on gender in Asia.
#
# **How we answer this question**: we will consider the Average Birth Rate and Death Rate for countries across all the year.

# %% [markdown]
# **YOUR ANSWER HERE**

# %% [markdown]
# ### Pre-processing

# %% [markdown]
# ### Analyzing to get the answer

# %% [markdown]
# ## Making your own question 06? (1.5 points)

# %% [markdown]
# **Question :** How is gender distributed over the time ?
#
# **Answering this question will** help us to see the current population distribution status and also understand more about current thinking on gender in Asia.
#
# **How we answer this question**: we will consider the Average Birth Rate and Death Rate for countries across all the year.

# %% [markdown]
# **YOUR ANSWER HERE**

# %% [markdown]
# ### Pre-processing

# %% [markdown]
# ### Analyzing to get the answer

# %% [markdown]
# ## Making your own question 07? (1.5 points)

# %% [markdown]
# **Question :** How is gender distributed over the time ?
#
# **Answering this question will** help us to see the current population distribution status and also understand more about current thinking on gender in Asia.
#
# **How we answer this question**: we will consider the Average Birth Rate and Death Rate for countries across all the year.

# %% [markdown]
# **YOUR ANSWER HERE**

# %% [markdown]
# ### Pre-processing

# %% [markdown]
# ### Analyzing to get the answer

# %% [markdown]
# ## Making your own question 08? (1.5 points)

# %% [markdown]
# **Question :** How is gender distributed over the time ?
#
# **Answering this question will** help us to see the current population distribution status and also understand more about current thinking on gender in Asia.
#
# **How we answer this question**: we will consider the Average Birth Rate and Death Rate for countries across all the year.

# %% [markdown]
# **YOUR ANSWER HERE**

# %% [markdown]
# ### Pre-processing

# %% [markdown]
# ### Analyzing to get the answer
